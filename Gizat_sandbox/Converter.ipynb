# %% [markdown]
# ## Convert CSV to GeoJSON

# %%
import pandas
import json

# %%
data_frame = pandas.read_csv('data/raw/NitratesGroundwater.csv')
data_frame[data_frame.columns[:]].head()
# Out:
#    Unnamed: 0                                                @id  \
# 0           1  http://environment.data.gov.uk/water-quality/d...
# 1           2  http://environment.data.gov.uk/water-quality/d...
# 2           3  http://environment.data.gov.uk/water-quality/d...
# 3           4  http://environment.data.gov.uk/water-quality/d...
# 4           5  http://environment.data.gov.uk/water-quality/d...
#
#                                 sample.samplingPoint  \
# 0  http://environment.data.gov.uk/water-quality/i...
# 1  http://environment.data.gov.uk/water-quality/i...
# 2  http://environment.data.gov.uk/water-quality/i...
# 3  http://environment.data.gov.uk/water-quality/i...
# 4  http://environment.data.gov.uk/water-quality/i...
#
#   sample.samplingPoint.notation sample.samplingPoint.label  \
# 0                   AN-FOXCVERT    HELPSTON FOX COVERT B/H
# 1                   AN-FOXCVERT    HELPSTON FOX COVERT B/H
# 2                   AN-FOXCVERT    HELPSTON FOX COVERT B/H
# 3                   AN-FOXCVERT    HELPSTON FOX COVERT B/H
# 4                   AN-FOXCVERT    HELPSTON FOX COVERT B/H
#
#   sample.sampleDateTime determinand.label determinand.definition  \
# 0   2000-01-12 09:45:00         Nitrate-N           Nitrate as N
# 1   2000-02-04 09:55:00         Nitrate-N           Nitrate as N
# 2   2000-03-17 10:05:00         Nitrate-N           Nitrate as N
# 3   2000-04-20 09:25:00         Nitrate-N           Nitrate as N
# 4   2000-05-24 13:25:00         Nitrate-N           Nitrate as N
#
#    determinand.notation resultQualifier.notation  result  \
# 0                   117                        <   0.100
# 1                   117                      NaN   0.498
# 2                   117                        <   0.100
# 3                   117                        <   0.100
# 4                   117                        <   0.100
#
#    codedResultInterpretation.interpretation determinand.unit.label  \
# 0                                       NaN                   mg/l
# 1                                       NaN                   mg/l
# 2                                       NaN                   mg/l
# 3                                       NaN                   mg/l
# 4                                       NaN                   mg/l
#
#   sample.sampledMaterialType.label  sample.isComplianceSample  \
# 0                      GROUNDWATER                      False
# 1                      GROUNDWATER                      False
# 2                      GROUNDWATER                      False
# 3                      GROUNDWATER                      False
# 4                      GROUNDWATER                      False
#
#                        sample.purpose.label  sample.samplingPoint.easting  \
# 0  PLANNED INVESTIGATION (LOCAL MONITORING)                        516360
# 1  PLANNED INVESTIGATION (LOCAL MONITORING)                        516360
# 2  PLANNED INVESTIGATION (LOCAL MONITORING)                        516360
# 3  PLANNED INVESTIGATION (LOCAL MONITORING)                        516360
# 4  PLANNED INVESTIGATION (LOCAL MONITORING)                        516360
#
#    sample.samplingPoint.northing
# 0                         305085
# 1                         305085
# 2                         305085
# 3                         305085
# 4                         305085

# %%
data_frame.dtypes
# Out:
# Unnamed: 0                                    int64
# @id                                          object
# sample.samplingPoint                         object
# sample.samplingPoint.notation                object
# sample.samplingPoint.label                   object
# sample.sampleDateTime                        object
# determinand.label                            object
# determinand.definition                       object
# determinand.notation                          int64
# resultQualifier.notation                     object
# result                                      float64
# codedResultInterpretation.interpretation    float64
# determinand.unit.label                       object
# sample.sampledMaterialType.label             object
# sample.isComplianceSample                      bool
# sample.purpose.label                         object
# sample.samplingPoint.easting                  int64
# sample.samplingPoint.northing                 int64
# dtype: object

# %%
import os
import pandas as pd
import pyproj

inProj = pyproj.Proj(init='epsg:27700')
outProj = pyproj.Proj(init='epsg:4326')

def proj_transform(row):
    long, lat = transform(inProj, outProj, row["sample.samplingPoint.easting"], row["sample.samplingPoint.northing"])
    
    row['long'] = long
    row['lat'] = lat
    return pd.Series(row)

data_frame_4326 = data_frame.apply(proj_transform, axis=1)

# %%
data_frame_4326.head()
# Out:
#    Unnamed: 0                                                @id  \
# 0           1  http://environment.data.gov.uk/water-quality/d...
# 1           2  http://environment.data.gov.uk/water-quality/d...
# 2           3  http://environment.data.gov.uk/water-quality/d...
# 3           4  http://environment.data.gov.uk/water-quality/d...
# 4           5  http://environment.data.gov.uk/water-quality/d...
#
#                                 sample.samplingPoint  \
# 0  http://environment.data.gov.uk/water-quality/i...
# 1  http://environment.data.gov.uk/water-quality/i...
# 2  http://environment.data.gov.uk/water-quality/i...
# 3  http://environment.data.gov.uk/water-quality/i...
# 4  http://environment.data.gov.uk/water-quality/i...
#
#   sample.samplingPoint.notation sample.samplingPoint.label  \
# 0                   AN-FOXCVERT    HELPSTON FOX COVERT B/H
# 1                   AN-FOXCVERT    HELPSTON FOX COVERT B/H
# 2                   AN-FOXCVERT    HELPSTON FOX COVERT B/H
# 3                   AN-FOXCVERT    HELPSTON FOX COVERT B/H
# 4                   AN-FOXCVERT    HELPSTON FOX COVERT B/H
#
#   sample.sampleDateTime determinand.label determinand.definition  \
# 0   2000-01-12 09:45:00         Nitrate-N           Nitrate as N
# 1   2000-02-04 09:55:00         Nitrate-N           Nitrate as N
# 2   2000-03-17 10:05:00         Nitrate-N           Nitrate as N
# 3   2000-04-20 09:25:00         Nitrate-N           Nitrate as N
# 4   2000-05-24 13:25:00         Nitrate-N           Nitrate as N
#
#    determinand.notation resultQualifier.notation  result  \
# 0                   117                        <   0.100
# 1                   117                      NaN   0.498
# 2                   117                        <   0.100
# 3                   117                        <   0.100
# 4                   117                        <   0.100
#
#    codedResultInterpretation.interpretation determinand.unit.label  \
# 0                                       NaN                   mg/l
# 1                                       NaN                   mg/l
# 2                                       NaN                   mg/l
# 3                                       NaN                   mg/l
# 4                                       NaN                   mg/l
#
#   sample.sampledMaterialType.label  sample.isComplianceSample  \
# 0                      GROUNDWATER                      False
# 1                      GROUNDWATER                      False
# 2                      GROUNDWATER                      False
# 3                      GROUNDWATER                      False
# 4                      GROUNDWATER                      False
#
#                        sample.purpose.label  sample.samplingPoint.easting  \
# 0  PLANNED INVESTIGATION (LOCAL MONITORING)                        516360
# 1  PLANNED INVESTIGATION (LOCAL MONITORING)                        516360
# 2  PLANNED INVESTIGATION (LOCAL MONITORING)                        516360
# 3  PLANNED INVESTIGATION (LOCAL MONITORING)                        516360
# 4  PLANNED INVESTIGATION (LOCAL MONITORING)                        516360
#
#    sample.samplingPoint.northing      long        lat
# 0                         305085 -0.282177  52.631056
# 1                         305085 -0.282177  52.631056
# 2                         305085 -0.282177  52.631056
# 3                         305085 -0.282177  52.631056
# 4                         305085 -0.282177  52.631056

# %%
data_frame_4326.rename(columns={'Unnamed: 0':'id'}, inplace=True)

# %%
json_result_string = data_frame_4326.to_json(
    orient='records', 
    double_precision=12,
    date_format='iso'
)
json_result = json.loads(json_result_string)

# %%
geojson = {
    'type': 'FeatureCollection',
    'features': []
}
for record in json_result:
    geojson['features'].append({
        'type': 'Feature',
        'properties' : {     # Can also be written as 'properties': record to include all
            'id' : recrod['Unnamed: 0'],
            'X1' : record['X1'],
            'samplingPointNotation' : record['samplingPointNotation'],
            'samplingPointLabel' : record['samplingPointLabel'],
            'sampleDateTime' : record['sampleDateTime'],
            'determinandLabel' : record['determinandLabel'],
            'result' : record['result'],
            'sampledMaterialTypeLabel' : record['sampledMaterialTypeLabel']
        },
        'geometry': {
            'type': 'Point',
            'coordinates': [record['lon'], record['lat']]
        }
    })

# %%
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.521481813791, 52.219942389223]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9452.0,
#     'samplingPointNotation': 'AN-11M12',
#     'samplingPointLabel': 'R.OUSE SHARNBROOK MILL',
#     'sampleDateTime': '2010-09-17 10:25:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 4.56,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.521481813791, 52.219942389223]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9458.0,
#     'samplingPointNotation': 'AN-11M12',
#     'samplingPointLabel': 'R.OUSE SHARNBROOK MILL',
#     'sampleDateTime': '2010-09-17 10:25:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0249,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.521481813791, 52.219942389223]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9484.0,
#     'samplingPointNotation': 'AN-11M12',
#     'samplingPointLabel': 'R.OUSE SHARNBROOK MILL',
#     'sampleDateTime': '2010-10-12 15:27:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0333,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.521481813791, 52.219942389223]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9486.0,
#     'samplingPointNotation': 'AN-11M12',
#     'samplingPointLabel': 'R.OUSE SHARNBROOK MILL',
#     'sampleDateTime': '2010-10-12 15:27:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 5.09,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.521481813791, 52.219942389223]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9491.0,
#     'samplingPointNotation': 'AN-11M12',
#     'samplingPointLabel': 'R.OUSE SHARNBROOK MILL',
#     'sampleDateTime': '2010-11-05 14:20:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 6.0,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.521481813791, 52.219942389223]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9493.0,
#     'samplingPointNotation': 'AN-11M12',
#     'samplingPointLabel': 'R.OUSE SHARNBROOK MILL',
#     'sampleDateTime': '2010-11-05 14:20:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0255,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.521481813791, 52.219942389223]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9528.0,
#     'samplingPointNotation': 'AN-11M12',
#     'samplingPointLabel': 'R.OUSE SHARNBROOK MILL',
#     'sampleDateTime': '2010-12-03 15:00:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 7.0,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.521481813791, 52.219942389223]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9530.0,
#     'samplingPointNotation': 'AN-11M12',
#     'samplingPointLabel': 'R.OUSE SHARNBROOK MILL',
#     'sampleDateTime': '2010-12-03 15:00:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0455,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.521481813791, 52.219942389223]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9550.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-02-11 14:55:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0642,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9551.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-02-11 14:55:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 8.52,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9568.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-03-05 14:05:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0298,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9573.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-03-05 14:05:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 7.06,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9580.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-03-24 11:40:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 6.97,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9582.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-03-24 11:40:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0239,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9602.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-04-29 10:50:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 5.35,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9604.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-04-29 10:50:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0187,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9623.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-06-09 12:30:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 3.9,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9636.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-06-09 12:30:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.035,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9653.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-07-02 12:10:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0209,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9661.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-07-02 12:10:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 3.22,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9673.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-07-28 11:35:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 2.85,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9675.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-07-28 11:35:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0155,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9690.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-08-24 10:30:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 3.08,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9692.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-08-24 10:30:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0179,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9716.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-09-06 13:23:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 4.11,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9718.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-09-06 13:23:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0209,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9735.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-10-06 15:25:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 4.54,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9737.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-10-06 15:25:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0279,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9763.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-11-08 15:25:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0168,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9770.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-11-08 15:25:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 5.92,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9787.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-12-01 13:54:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 6.87,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9792.0,
#     'samplingPointNotation': 'AN-11M14',
#     'samplingPointLabel': 'R.OUSE KEMPSTON MILL',
#     'sampleDateTime': '2010-12-01 13:54:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0251,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.505864798302, 52.118145290716]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9800.0,
#     'samplingPointNotation': 'AN-11M19',
#     'samplingPointLabel': 'SHARNBROOK(YELNOE BK) D/S COLWORTH HOUSE',
#     'sampleDateTime': '2010-02-03 12:10:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 8.71,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.550484898197, 52.228394102229]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9801.0,
#     'samplingPointNotation': 'AN-11M19',
#     'samplingPointLabel': 'SHARNBROOK(YELNOE BK) D/S COLWORTH HOUSE',
#     'sampleDateTime': '2010-02-03 12:10:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.015,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.550484898197, 52.228394102229]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9816.0,
#     'samplingPointNotation': 'AN-11M19',
#     'samplingPointLabel': 'SHARNBROOK(YELNOE BK) D/S COLWORTH HOUSE',
#     'sampleDateTime': '2010-03-19 16:25:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 7.33,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.550484898197, 52.228394102229]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9826.0,
#     'samplingPointNotation': 'AN-11M19',
#     'samplingPointLabel': 'SHARNBROOK(YELNOE BK) D/S COLWORTH HOUSE',
#     'sampleDateTime': '2010-03-19 16:25:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0082,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.550484898197, 52.228394102229]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9839.0,
#     'samplingPointNotation': 'AN-11M19',
#     'samplingPointLabel': 'SHARNBROOK(YELNOE BK) D/S COLWORTH HOUSE',
#     'sampleDateTime': '2010-03-31 13:14:00',
#     'determinandLabel': 'Nitrite-N',
#     'result': 0.0256,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.550484898197, 52.228394102229]}},
#   {'type': 'Feature',
#    'properties': {'X1': 9842.0,
#     'samplingPointNotation': 'AN-11M19',
#     'samplingPointLabel': 'SHARNBROOK(YELNOE BK) D/S COLWORTH HOUSE',
#     'sampleDateTime': '2010-03-31 13:14:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 5.72,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.550484898197, 52.228394102229]}},
#   {'type': 'Feature',
#    'properties': {'X1': 10020.0,
#     'samplingPointNotation': 'AN-11M37',
#     'samplingPointLabel': 'CHICHELEY BK. CHICHELEY RD.BR.',
#     'sampleDateTime': '2010-06-22 10:36:00',
#     'determinandLabel': 'Nitrate-N',
#     'result': 11.4,
#     'sampledMaterialTypeLabel': 'RIVER / RUNNING SURFACE WATER'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-0.676039286419, 52.099768867952]}},
#   ...]}

# %%
with open('test.geojson', 'w') as json_file:  
    json.dump(geojson, json_file, indent=4)

# %%
print("Min is: " + str(data_frame['result'].min()))
print("Mean is: " + str(data_frame['result'].mean()))
print("Max is: " + str(data_frame['result'].max()))
# Out:
# Min is: 1e-05
# Mean is: 3.166230152827276
# Max is: 24700.0

# %%
data_frame_4326.to_csv("data/NitratesGroundwater_4326.csv")
